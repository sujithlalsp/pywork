# %%
import matplotlib.pyplot as plt
import numpy as np
import xarray as xr
from matplotlib.dates import DateFormatter
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import numpy as np

# %%
ds= xr.open_dataset('/home/sps/Downloads/NETCDF5_kochi_weather_2019 MAY_21_to_25/NETCDF5_kochi_weather_2019_05_24_18_02_06.nc')
print (ds)

data2=ds['siteLat']
print (data2)

print (data3)


data4=ds['gateSize']
print (data4)

data5=ds['radialElev']
print (data5)


data1=ds['Z'][0,:,:]
print (data1)
#data=data1.mask(data1 > 50)

data=data1.where(data1>0)


#N = 360


fig = plt.figure(figsize=(12, 6))
ax = fig.add_subplot(111, projection='polar')
# Out:
# <xarray.Dataset>
# Dimensions:          (bin: 800, radial: 360, sweep: 10)
# Dimensions without coordinates: bin, radial, sweep
# Data variables:
#     esStartTime      float64 ...
#     elevationNumber  int16 ...
#     radialAzim       (radial) float32 ...
#     radialElev       (radial) float32 ...
#     radialTime       (radial) float64 ...
#     siteLat          float32 ...
#     siteLon          float32 ...
#     siteAlt          float32 ...
#     firstgateRange   float32 ...
#     gateSize         float32 ...
#     nyquist          float32 ...
#     unambigrange     float32 ...
#     RadarConst       float32 ...
#     beamWidthHori    float32 ...
#     pulseWidth       float32 ...
#     elevationList    (sweep) float32 ...
#     azimuthSpeed     float32 ...
#     highPRF          float32 ...
#     lowPRF           float32 ...
#     waveLength       float32 ...
#     groundHeight     float32 ...
#     angleResolution  float32 ...
#     sampleNum        int32 ...
#     SQIThresh        float32 ...
#     LOGThresh        float32 ...
#     beamWidthVert    float32 ...
#     Z                (sweep, radial, bin) float32 ...
#     V                (sweep, radial, bin) float32 ...
#     W                (sweep, radial, bin) float32 ...
#     ZDR              (sweep, radial, bin) float32 ...
#     PHIDP            (sweep, radial, bin) float32 ...
#     RHOHV            (sweep, radial, bin) float32 ...
# Attributes:
#     Content:      This file contains one volume scan data of DWR
#     title:        C Band DWR data
#     history:      DWR data encoded into NetCDF
#     Conventions:  FSL NetCDF
# <xarray.DataArray 'siteLat' ()>
# array(9.9263, dtype=float32)
# Attributes:
#     units:      degrees_north
#     long_name:  Lattitude of site
# <xarray.DataArray 'siteLon' ()>
# array(76.2622, dtype=float32)
# Attributes:
#     units:      degrees_east
#     long_name:  Longitude of site
# <xarray.DataArray 'gateSize' ()>
# array(300., dtype=float32)
# Attributes:
#     units:      meter
#     long_name:  Gate spacing
# <xarray.DataArray 'radialElev' (radial: 360)>
# array([0.5, 0.5, 0.5, ..., 0.5, 0.5, 0.5], dtype=float32)
# Dimensions without coordinates: radial
# Attributes:
#     units:      degree
#     long_name:  Radial Elevation Angle
# <xarray.DataArray 'Z' (radial: 360, bin: 800)>
# [288000 values with dtype=float32]
# Dimensions without coordinates: radial, bin
# Attributes:
#     units:      dBZ
#     long_name:  Reflectivity

# %%
a = np.radians(np.linspace(0, 360, 360))
b = np.arange(0, 800, 1)
 
r, theta = np.meshgrid(b,a)
values =data
 
fig, ax = plt.subplots(subplot_kw=dict(projection='polar'))
#ax.contourf(theta, r, values)
 


plt.pcolormesh(theta, r, values,cmap=plt.cm.jet,vmin =0, vmax =40)
# #cbar = plt.colorbar(cs, shrink=0.5)
# #cbar.set_clim(-30, 45)data1
plt.title('reflectivity(dBz)')
# formatter = DateFormatter('%d')
#plt.xticks([])
plt.yticks([])
# #plt.ylim(0,20)
plt.colorbar()
plt.savefig('/home/sps/Desktop/radarreflectivity.jpg',dpi=700)
